# %%
import sys
import scanpy as sc

sys.path.append("../..")
from scripts.runner_models import cv_baselines_5fold

# %%
# Load data
IN_PATH_neu = "../data/raw_count/GSE169569_raw_counts.h5ad"
IN_PATH_cov = "../data/raw_count/GSE228841_raw_counts.h5ad"

adata_neu = sc.read_h5ad(IN_PATH_neu)
adata_cov = sc.read_h5ad(IN_PATH_cov)

# %%
import numpy as np

# Extract data matrices and metadata
X_counts = adata_neu.layers["counts"] # raw counts
gene_names = np.array(adata_neu.var_names, dtype=str)
batches = np.array(adata_neu.obs["BioProject"], dtype=str)
norm_layer = adata_neu.layers["log2_1p_CPM_original"]

# %%
# CORRECT call for the new 5-fold baseline runner
summary_df, details_df = cv_baselines_5fold(
    X_counts,
    k=5,
    model_grids={
        "MEAN":   {},
        "MEDIAN": {},
        "KNN":    {"n_neighbors": [5, 15, 30], "weights": ["uniform", "distance"]},
        "MAGIC":  {"n_pca": [None, 50], "t": [3], "knn": [5, 10]},
    },
    n_hvg=2000,                 # pick one number of HVGs (train-fold only)
    R=3,
    mask_frac=0.10,             # Nonzero-Zeroing rate
    thinning_p=0.10,            # Binomial-Thinning holdout prob
    random_state=123,
    save_dir="results/baselines",# CSVs will be written here
    hvg_mode="seurat_v3",
    gene_names=gene_names,
    batches=batches,
    norm_layer=norm_layer,       # e.g., adata.layers["log2_1p_CPM_original"]
    batch_key="BioProject",
    seurat_layer_name="log2_1p_CPM_original",
    # labels=celltype_labels,    # optional for Silhouette
)
# Out:
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   return fn(*args_all, **kw)
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating KNN search...
#   Calculated KNN search in 0.11 seconds.
#   Calculating affinities...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (357, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#   Calculated affinities in 1.17 seconds.
# Calculated graph and diffusion operator in 1.28 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.07 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.04 seconds.
# Calculated MAGIC in 0.09 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.03 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.05 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 0.06 seconds.
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.07 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.03 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculated MAGIC in 0.03 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.03 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.02 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (357, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.03 seconds.
#   Calculated graph and diffusion operator in 0.05 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.09 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.06 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.05 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 0.03 seconds.
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.03 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/legacy_api_wrap/__init__.py:82: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   return fn(*args_all, **kw)
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: invalid value encountered in multiply
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# /Users/mjlee/master_thesis/Thesis_project/notebooks/../scripts/utilities.py:59: RuntimeWarning: divide by zero encountered in log1p
#   + r * np.log(p) + x * np.log1p(-p))
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating KNN search...
#   Calculating affinities...
#   Calculated affinities in 0.01 seconds.
# Calculated graph and diffusion operator in 0.03 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.03 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.05 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.06 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.02 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.04 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (357, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.06 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.04 seconds.
#   Calculated graph and diffusion operator in 0.07 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.11 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.07 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#   Calculated imputation in 0.10 seconds.
# Calculated MAGIC in 0.17 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 0.02 seconds.
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.03 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.03 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.02 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.02 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.04 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (357, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.08 seconds.
# Calculated MAGIC in 0.11 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.05 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.06 seconds.
# Running MAGIC on 357 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 0.03 seconds.
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# ...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.03 seconds.
#     Calculating KNN search...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.04 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Running MAGIC on 358 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.02 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.06 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (358, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.01 seconds.
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.03 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.02 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.01 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.01 seconds.
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.05 seconds.
# Running MAGIC on 358 cells and 2000 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 0.02 seconds.
#   Calculating KNN search...
#   Calculating affinities...
# Calculated graph and diffusion operator in 0.03 seconds.
# Calculating imputation...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/graphtools/graphs.py:473: UserWarning: Building a kNNGraph on data of shape (447, 2000) is expensive. Consider setting n_pca.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.14 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.16 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.20 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# Calculating imputation...
# Calculating MAGIC...
#   Running MAGIC on 447 cells and 2000 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.02 seconds.
#     Calculating KNN search...
#     Calculating affinities...
#   Calculated graph and diffusion operator in 0.03 seconds.
#   Calculating imputation...
# Calculated MAGIC in 0.04 seconds.
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(
# /Users/mjlee/master_thesis/Thesis_project/thesispjt/thesis-impute/lib/python3.12/site-packages/magic/magic.py:541: UserWarning: Running MAGIC.transform on different data to that which was used for MAGIC.fit may not produce sensible output, unless it comes from the same manifold.
#   warnings.warn(

# %%
summary_df
# Out:
#      model  n_hvg    MAE_zero      MSE_zero  MedianL1_zero  NB_ll_zero  \
# 0      KNN   2000  145.182524  3.973526e+06       4.792379        -inf
# 1      KNN   2000  146.401514  3.977597e+06       4.880000        -inf
# 2      KNN   2000  145.935892  3.813152e+06       5.468255        -inf
# 3      KNN   2000  148.851010  3.923409e+06       5.600000        -inf
# 4      KNN   2000  152.806336  4.116963e+06       5.955009   -8.618125
# 5      KNN   2000  157.783914  4.289946e+06       6.163333   -8.626906
# 6    MAGIC   2000  117.391397  1.452627e+06       6.251003   -4.460702
# 7    MAGIC   2000  117.419249  1.452795e+06       6.249631   -4.460723
# 8    MAGIC   2000  136.522088  2.423615e+06       6.917324   -4.488520
# 9    MAGIC   2000  136.533152  2.423911e+06       6.917520   -4.488540
# 10    MEAN   2000  450.904811  4.780094e+07       8.908444   -4.595289
# 11  MEDIAN   2000  439.363050  4.895885e+07       4.633333        -inf
#
#     NB_dev_zero   MAE_thin       MSE_thin  MedianL1_thin  NB_ll_thin  \
# 0     19.890789  22.624352  232493.451225       0.342620   -1.050366
# 1     19.890562  22.624352  232493.451225       0.342620   -1.050366
# 2     10.073955  22.624352  232493.451225       0.342620   -1.050366
# 3     10.081122  22.624352  232493.451225       0.342620   -1.050366
# 4      8.615290  22.624352  232493.451225       0.342620   -1.050366
# 5      8.632852  22.624352  232493.451225       0.342620   -1.050366
# 6      0.300443   7.082175   11648.230403       0.175739   -0.967150
# 7      0.300485   7.082792   11648.964590       0.175767   -0.967162
# 8      0.356079   7.811972   15521.961188       0.201358   -0.980229
# 9      0.356119   7.812378   15523.153214       0.201368   -0.980244
# 10     0.569616  22.624352  232493.451225       0.342620   -1.050366
# 11   634.094426  21.647104  238600.540592       0.000000  -15.025155
#
#     NB_dev_thin Silhouette                                      params
# 0      0.450777        NaN   {'n_neighbors': 5, 'weights': 'distance'}
# 1      0.450777        NaN    {'n_neighbors': 5, 'weights': 'uniform'}
# 2      0.450777        NaN  {'n_neighbors': 15, 'weights': 'distance'}
# 3      0.450777        NaN   {'n_neighbors': 15, 'weights': 'uniform'}
# 4      0.450777        NaN  {'n_neighbors': 30, 'weights': 'distance'}
# 5      0.450777        NaN   {'n_neighbors': 30, 'weights': 'uniform'}
# 6      0.284345        NaN             {'knn': 5, 'n_pca': 50, 't': 3}
# 7      0.284369        NaN           {'knn': 5, 'n_pca': None, 't': 3}
# 8      0.310503        NaN            {'knn': 10, 'n_pca': 50, 't': 3}
# 9      0.310534        NaN          {'knn': 10, 'n_pca': None, 't': 3}
# 10     0.450777        NaN                                          {}
# 11    27.921103        NaN                                          {}

# %%
details_df
# Out:
#     fold   model                                      params  n_hvg  \
# 0      1    MEAN                                          {}   2000
# 1      1  MEDIAN                                          {}   2000
# 2      1     KNN    {'n_neighbors': 5, 'weights': 'uniform'}   2000
# 3      1     KNN   {'n_neighbors': 5, 'weights': 'distance'}   2000
# 4      1     KNN   {'n_neighbors': 15, 'weights': 'uniform'}   2000
# 5      1     KNN  {'n_neighbors': 15, 'weights': 'distance'}   2000
# 6      1     KNN   {'n_neighbors': 30, 'weights': 'uniform'}   2000
# 7      1     KNN  {'n_neighbors': 30, 'weights': 'distance'}   2000
# 8      1   MAGIC           {'knn': 5, 'n_pca': None, 't': 3}   2000
# 9      1   MAGIC             {'knn': 5, 'n_pca': 50, 't': 3}   2000
# 10     1   MAGIC          {'knn': 10, 'n_pca': None, 't': 3}   2000
# 11     1   MAGIC            {'knn': 10, 'n_pca': 50, 't': 3}   2000
# 12     2    MEAN                                          {}   2000
# 13     2  MEDIAN                                          {}   2000
# 14     2     KNN    {'n_neighbors': 5, 'weights': 'uniform'}   2000
# 15     2     KNN   {'n_neighbors': 5, 'weights': 'distance'}   2000
# 16     2     KNN   {'n_neighbors': 15, 'weights': 'uniform'}   2000
# 17     2     KNN  {'n_neighbors': 15, 'weights': 'distance'}   2000
# 18     2     KNN   {'n_neighbors': 30, 'weights': 'uniform'}   2000
# 19     2     KNN  {'n_neighbors': 30, 'weights': 'distance'}   2000
# 20     2   MAGIC           {'knn': 5, 'n_pca': None, 't': 3}   2000
# 21     2   MAGIC             {'knn': 5, 'n_pca': 50, 't': 3}   2000
# 22     2   MAGIC          {'knn': 10, 'n_pca': None, 't': 3}   2000
# 23     2   MAGIC            {'knn': 10, 'n_pca': 50, 't': 3}   2000
# 24     3    MEAN                                          {}   2000
# 25     3  MEDIAN                                          {}   2000
# 26     3     KNN    {'n_neighbors': 5, 'weights': 'uniform'}   2000
# 27     3     KNN   {'n_neighbors': 5, 'weights': 'distance'}   2000
# 28     3     KNN   {'n_neighbors': 15, 'weights': 'uniform'}   2000
# 29     3     KNN  {'n_neighbors': 15, 'weights': 'distance'}   2000
# 30     3     KNN   {'n_neighbors': 30, 'weights': 'uniform'}   2000
# 31     3     KNN  {'n_neighbors': 30, 'weights': 'distance'}   2000
# 32     3   MAGIC           {'knn': 5, 'n_pca': None, 't': 3}   2000
# 33     3   MAGIC             {'knn': 5, 'n_pca': 50, 't': 3}   2000
# 34     3   MAGIC          {'knn': 10, 'n_pca': None, 't': 3}   2000
# 35     3   MAGIC            {'knn': 10, 'n_pca': 50, 't': 3}   2000
# 36     4    MEAN                                          {}   2000
# 37     4  MEDIAN                                          {}   2000
# 38     4     KNN    {'n_neighbors': 5, 'weights': 'uniform'}   2000
# 39     4     KNN   {'n_neighbors': 5, 'weights': 'distance'}   2000
# 40     4     KNN   {'n_neighbors': 15, 'weights': 'uniform'}   2000
# 41     4     KNN  {'n_neighbors': 15, 'weights': 'distance'}   2000
# 42     4     KNN   {'n_neighbors': 30, 'weights': 'uniform'}   2000
# 43     4     KNN  {'n_neighbors': 30, 'weights': 'distance'}   2000
# 44     4   MAGIC           {'knn': 5, 'n_pca': None, 't': 3}   2000
# 45     4   MAGIC             {'knn': 5, 'n_pca': 50, 't': 3}   2000
# 46     4   MAGIC          {'knn': 10, 'n_pca': None, 't': 3}   2000
# 47     4   MAGIC            {'knn': 10, 'n_pca': 50, 't': 3}   2000
# 48     5    MEAN                                          {}   2000
# 49     5  MEDIAN                                          {}   2000
# 50     5     KNN    {'n_neighbors': 5, 'weights': 'uniform'}   2000
# 51     5     KNN   {'n_neighbors': 5, 'weights': 'distance'}   2000
# 52     5     KNN   {'n_neighbors': 15, 'weights': 'uniform'}   2000
# 53     5     KNN  {'n_neighbors': 15, 'weights': 'distance'}   2000
